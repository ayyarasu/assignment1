# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
url="https://www.flipkart.com/search?q=mobiles+under+15000&as=on&as-show=on&otracker=AS_Query_OrganicAutoSuggest_3_7_na_na_na&otracker1=AS_Query_OrganicAutoSuggest_3_7_na_na_na&as-pos=3&as-type=RECENT&suggestionId=mobiles+under+15000&requestId=f27baea5-52bc-4f27-bf17-eacb9b1f27a0&as-searchtext=mobiles"

# %%
permission=requests.get(url)

# %%
permission
# Out:
# <Response [200]>

# %%
link=BeautifulSoup(permission.text)

# %%
link
# Out:
# <!DOCTYPE html>
# ...

# %%
product=link.select("._4rR01T")

# %%
product
# Out:
# [<div class="_4rR01T">MOTOROLA G32 (Mineral Gray, 128 GB)</div>,
#  <div class="_4rR01T">realme C55 (Sunshower, 128 GB)</div>,
#  <div class="_4rR01T">MOTOROLA G32 (Satin Silver, 128 GB)</div>,
#  <div class="_4rR01T">realme C55 (Rainy Night, 128 GB)</div>,
#  <div class="_4rR01T">realme C55 (Rainy Night, 64 GB)</div>,
#  <div class="_4rR01T">realme C55 (Sunshower, 64 GB)</div>,
#  <div class="_4rR01T">MOTOROLA g31 (Meteorite Grey, 64 GB)</div>,
#  <div class="_4rR01T">realme C55 (Sunshower, 64 GB)</div>,
#  <div class="_4rR01T">realme C55 (Rainy Night, 64 GB)</div>,
#  <div class="_4rR01T">SAMSUNG Galaxy F14 5G (GOAT Green, 128 GB)</div>,
#  <div class="_4rR01T">MOTOROLA g52 (Metallic White, 128 GB)</div>,
#  <div class="_4rR01T">SAMSUNG Galaxy F13 (Nightsky Green, 64 GB)</div>,
#  <div class="_4rR01T">MOTOROLA g52 (Charcoal Grey, 64 GB)</div>,
#  <div class="_4rR01T">POCO M4 Pro (Cool Blue, 128 GB)</div>,
#  <div class="_4rR01T">SAMSUNG Galaxy F14 5G (OMG Black, 128 GB)</div>,
# ...

# %%
rate=link.select("._1_WHN1")

# %%
rate
# Out:
# [<div class="_30jeq3 _1_WHN1">₹12,099</div>,
#  <div class="_30jeq3 _1_WHN1">₹13,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹12,099</div>,
#  <div class="_30jeq3 _1_WHN1">₹13,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹11,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹11,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹12,099</div>,
#  <div class="_30jeq3 _1_WHN1">₹10,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹10,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹14,490</div>,
#  <div class="_30jeq3 _1_WHN1">₹14,099</div>,
#  <div class="_30jeq3 _1_WHN1">₹10,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹10,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹13,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹14,490</div>,
#  <div class="_30jeq3 _1_WHN1">₹14,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹11,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹12,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹12,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹14,099</div>,
#  <div class="_30jeq3 _1_WHN1">₹11,574</div>,
# ...

# %%
import pandas as pd

# %%
productlist=pd.DataFrame(product,columns=["products_name"])

# %%
productlist
# Out:
#                                  products_name
# 0          MOTOROLA G32 (Mineral Gray, 128 GB)
# 1               realme C55 (Sunshower, 128 GB)
# 2          MOTOROLA G32 (Satin Silver, 128 GB)
# 3             realme C55 (Rainy Night, 128 GB)
# 4              realme C55 (Rainy Night, 64 GB)
# 5                realme C55 (Sunshower, 64 GB)
# 6         MOTOROLA g31 (Meteorite Grey, 64 GB)
# 7                realme C55 (Sunshower, 64 GB)
# 8              realme C55 (Rainy Night, 64 GB)
# 9   SAMSUNG Galaxy F14 5G (GOAT Green, 128 GB)
# 10       MOTOROLA g52 (Metallic White, 128 GB)
# 11  SAMSUNG Galaxy F13 (Nightsky Green, 64 GB)
# 12         MOTOROLA g52 (Charcoal Grey, 64 GB)
# 13             POCO M4 Pro (Cool Blue, 128 GB)
# 14   SAMSUNG Galaxy F14 5G (OMG Black, 128 GB)
# 15              POCO M4 5G (Cool Blue, 128 GB)
# 16           REDMI 10 (Midnight Black, 128 GB)
# 17            POCO M4 Pro (Power Black, 64 GB)
# 18             POCO M4 5G (Power Black, 64 GB)
# ...

# %%
productlist["price"]=rate

# %%
productlist
# Out:
#                                  products_name      price
# 0          MOTOROLA G32 (Mineral Gray, 128 GB)  [₹12,099]
# 1               realme C55 (Sunshower, 128 GB)  [₹13,999]
# 2          MOTOROLA G32 (Satin Silver, 128 GB)  [₹12,099]
# 3             realme C55 (Rainy Night, 128 GB)  [₹13,999]
# 4              realme C55 (Rainy Night, 64 GB)  [₹11,999]
# 5                realme C55 (Sunshower, 64 GB)  [₹11,999]
# 6         MOTOROLA g31 (Meteorite Grey, 64 GB)  [₹12,099]
# 7                realme C55 (Sunshower, 64 GB)  [₹10,999]
# 8              realme C55 (Rainy Night, 64 GB)  [₹10,999]
# 9   SAMSUNG Galaxy F14 5G (GOAT Green, 128 GB)  [₹14,490]
# 10       MOTOROLA g52 (Metallic White, 128 GB)  [₹14,099]
# 11  SAMSUNG Galaxy F13 (Nightsky Green, 64 GB)  [₹10,999]
# 12         MOTOROLA g52 (Charcoal Grey, 64 GB)  [₹10,999]
# 13             POCO M4 Pro (Cool Blue, 128 GB)  [₹13,999]
# 14   SAMSUNG Galaxy F14 5G (OMG Black, 128 GB)  [₹14,490]
# ...

# %%
productlist.to_csv("D:/assignment.csv")

# %%
excel=pd.read_csv("D:/assignment.csv")

# %%
file=excel["price"]

# %%
file
# Out:
# 0     <div class="_30jeq3 _1_WHN1">₹12,099</div>
# 1     <div class="_30jeq3 _1_WHN1">₹13,999</div>
# 2     <div class="_30jeq3 _1_WHN1">₹12,099</div>
# 3     <div class="_30jeq3 _1_WHN1">₹13,999</div>
# 4     <div class="_30jeq3 _1_WHN1">₹11,999</div>
# 5     <div class="_30jeq3 _1_WHN1">₹11,999</div>
# 6     <div class="_30jeq3 _1_WHN1">₹12,099</div>
# 7     <div class="_30jeq3 _1_WHN1">₹10,999</div>
# 8     <div class="_30jeq3 _1_WHN1">₹10,999</div>
# 9     <div class="_30jeq3 _1_WHN1">₹14,490</div>
# 10    <div class="_30jeq3 _1_WHN1">₹14,099</div>
# 11    <div class="_30jeq3 _1_WHN1">₹10,999</div>
# 12    <div class="_30jeq3 _1_WHN1">₹10,999</div>
# 13    <div class="_30jeq3 _1_WHN1">₹13,999</div>
# 14    <div class="_30jeq3 _1_WHN1">₹14,490</div>
# 15    <div class="_30jeq3 _1_WHN1">₹14,999</div>
# 16    <div class="_30jeq3 _1_WHN1">₹11,999</div>
# 17    <div class="_30jeq3 _1_WHN1">₹12,999</div>
# 18    <div class="_30jeq3 _1_WHN1">₹12,999</div>
# ...

# %%
corrected=file.str.strip(' <div class="_30jeq3 _1_WHN1">').astype(str)

# %%
corrected
# Out:
# 0     ₹12,099</
# 1     ₹13,999</
# 2     ₹12,099</
# 3     ₹13,999</
# 4     ₹11,999</
# 5     ₹11,999</
# 6     ₹12,099</
# 7     ₹10,999</
# 8     ₹10,999</
# 9     ₹14,490</
# 10    ₹14,099</
# 11    ₹10,999</
# 12    ₹10,999</
# 13    ₹13,999</
# 14    ₹14,490</
# 15    ₹14,999</
# 16    ₹11,999</
# 17    ₹12,999</
# 18    ₹12,999</
# 19    ₹14,099</
# 20    ₹11,574</
# 21    ₹11,099</
# 22    ₹12,999</
# 23    ₹12,999</
# Name: price, dtype: object

# %%
corrected1=corrected.str.strip("</").astype(str)

# %%
corrected1
# Out:
# 0     ₹12,099
# 1     ₹13,999
# 2     ₹12,099
# 3     ₹13,999
# 4     ₹11,999
# 5     ₹11,999
# 6     ₹12,099
# 7     ₹10,999
# 8     ₹10,999
# 9     ₹14,490
# 10    ₹14,099
# 11    ₹10,999
# 12    ₹10,999
# 13    ₹13,999
# 14    ₹14,490
# 15    ₹14,999
# 16    ₹11,999
# 17    ₹12,999
# 18    ₹12,999
# 19    ₹14,099
# 20    ₹11,574
# 21    ₹11,099
# 22    ₹12,999
# 23    ₹12,999
# Name: price, dtype: object

# %%
productlist["price"]=corrected1

# %%
productlist
# Out:
#                                  products_name    price
# 0          MOTOROLA G32 (Mineral Gray, 128 GB)  ₹12,099
# 1               realme C55 (Sunshower, 128 GB)  ₹13,999
# 2          MOTOROLA G32 (Satin Silver, 128 GB)  ₹12,099
# 3             realme C55 (Rainy Night, 128 GB)  ₹13,999
# 4              realme C55 (Rainy Night, 64 GB)  ₹11,999
# 5                realme C55 (Sunshower, 64 GB)  ₹11,999
# 6         MOTOROLA g31 (Meteorite Grey, 64 GB)  ₹12,099
# 7                realme C55 (Sunshower, 64 GB)  ₹10,999
# 8              realme C55 (Rainy Night, 64 GB)  ₹10,999
# 9   SAMSUNG Galaxy F14 5G (GOAT Green, 128 GB)  ₹14,490
# 10       MOTOROLA g52 (Metallic White, 128 GB)  ₹14,099
# 11  SAMSUNG Galaxy F13 (Nightsky Green, 64 GB)  ₹10,999
# 12         MOTOROLA g52 (Charcoal Grey, 64 GB)  ₹10,999
# 13             POCO M4 Pro (Cool Blue, 128 GB)  ₹13,999
# 14   SAMSUNG Galaxy F14 5G (OMG Black, 128 GB)  ₹14,490
# 15              POCO M4 5G (Cool Blue, 128 GB)  ₹14,999
# ...

# %%
productlist.to_csv("D:/ayya assignment1.csv")
